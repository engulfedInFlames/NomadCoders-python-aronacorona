# %%
import plotly.express as px
from data_processing import make_final_df

df = make_final_df()

line
# Out:
# <div>                            <div id="888dc20a-b1cf-4721-8bbf-ba79f2839c14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("888dc20a-b1cf-4721-8bbf-ba79f2839c14")) {                    Plotly.newPlot(                        "888dc20a-b1cf-4721-8bbf-ba79f2839c14",                        [{"customdata":[["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["confirmed"],["co
# ...
